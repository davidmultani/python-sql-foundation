# %%
print("Hello DataBricks")
# Out:
# Hello DataBricks

# %%
data = [(1,"A"),(2,"B"),(3,"C"),(4,"D")]
df = spark.createDataFrame(data,["id","value"])
df.show()
# Out:
# +---+-----+
# | id|value|
# +---+-----+
# |  1|    A|
# |  2|    B|
# |  3|    C|
# |  4|    D|
# +---+-----+

# %% [markdown]
# What is Spark?
#
# Apache Spark is a distributed computing framework used to process large amounts of data very fast.
# It breaks big tasks into small tasks and runs them on multiple machines in parallel.

# %% [markdown]
# What is a DataFrame?
#
# A DataFrame in Spark is a distributed table with rows and columns, similar to:
#
# SQL table
#
# Pandas DataFrame
